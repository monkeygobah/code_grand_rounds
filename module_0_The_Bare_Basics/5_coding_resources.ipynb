# %%
# stack overflow and chat gpt how to make best use of

# %% [markdown]
# # **Code Like a Pro: Online Resources**
#
#
#
# ### As you will soon see, coding is just high level problem-solving. When you are writing code to tackle a large, challenging problem, you start by breaking it up into multiple smaller components. This is called thinking programmatically, and it is a core aspect of learning to develop your own algorithms. If you were writing an algorithm on how to make a pizza, it would be pretty intuitive. Step 1, roll the dough. Step 2, turn on the oven. Step 3, tomato sauce, etc etc. While you ultimately want to make a pizza, you have to solve little micro problems throughout the process in order to complete your task.
#
# ![image-5.png](attachment:image-5.png)
#
# ### That being said, the problems you have to solve when building algorithms can sometimes be more vague than the steps to making pizza. There is lots of data to keep track of, moving parts, maybe you forgot what a part of your code you wrote last week does, who knows- but the bottom line is it can quickly become daunting when you are embarking on this journey.
#
# ### BUT! We are here to tell you that you are not alone in this fear, and that this process of running into a problem you are not quite sure how to fix is, quite literally, about 95% of programming. With some practice, it will take you about 30 min to set up a full length algorithm, but a few weeks to debug it and get it working. Does this mean that all computer scientists are elite problem solving geniuses, absolutely, 100% NOT! While you will definitely become better at solving problems as you work through Code Grand Rounds, any computer scientist will tell you that one of their best skills is knowing how to use Google and other tools effectively to get the answers they need to work through problems that arise.
#
# ### In fact, for almost all of coding tasks you will work through (particularly if you are coming from a primarily medical background) someone will have done something similar before, and they will have faced similar challenges. As such, there is a plethora of resources freely available to you to that we want to show you right out of the gate to get you ready to tackle these challenges head on. Just remember that a considerable part of coding involves looking up solutions, researching techniques, and learning from others. Googling problems as they arise isn't a sign of weakness or ineptitude; **it's a sign of resourcefulness and adaptability.** Embrace it, because it's a fundamental part of the coding process, and you will be better for it!
#
# ## **Stack Overflow**
#
# ### Stack Overflow is a site that every person who has ever written a line of code has visited has been to. It is the go to community for people to ask questions to the coding community and receive crowd sourced answers. It is essentially a large forum where you can make an account if you want to post or reply, but everyone can view the questions and answers asked.
#
# ![image.png](attachment:image.png)
#
# ### Imagine you are working on an algorithm and you keep getting an error. The first thing you want to do is read the error to try and figure out what is going on, but a very close second if and when you can't figure it out is to copy and paste the error into google followed by the words `stack overflow` and see what pops up. You can also ask questions. I asked the following question `how to print hello world stack overflow` and clicked on the first link to find this page:
#
# ![image-2.png](attachment:image-2.png)
#
# ### with this answer:
#
# ![image-3.png](attachment:image-3.png)
#
# ### and boom- problem solved. The little green checkmark on Stack Overflow normally indicates that whoever asked the question marked this answer as the best response. When you see the green checkmark, normally that means it is a pretty good answer, but of course, make sure to doublecheck what is written just to see if it makes sense in your context.
#
# ### Another handy part of Stack Overflow is that in addition to the actual responses to the original question you can also see read peoples comments below the answers. It is often that if the the original posted answer didn't work, someone in the comments will have a good fix and post it there.
#
# ![image-4.png](attachment:image-4.png)
#
# ### This is a process that you can and should get familiar with! Even if you're not having an error specifically and just want to understand a concept, Stack is a great place to go for advice.
#
# ### An obligatory warning- even though a lot of the stuff on Stack is really, really good, there is stil some not so good advice on there, so always proceed with caution and use your best judgement. In addition, make sure to really try and udnerstand the solution that is posted instead of just copy and pasting. If everyone uses Stack Overflow, everyone has also copy and pasted a Stack Overflow answer at least once to find that it works, but that doesn't make it right and you should always always always make an effort to understand every line of code in your algorithms.
#
# ## **ChatGPT**
#
# ### While Stack Overflow will be around forever, since its inception ChatGPT has become quite literally an invaluable tool for programmers everywhere. In fact, I think it is safe to say that if you are just starting this journey you are starting at the best time in history due to how massively powerful ChatGPT is.
#
# ### For those late to the party, ChatGPT is a state of the art large language model (AI to interact with human language) that is trained on a massive corpus of literature, including extremely large volumes of computer code. As such, ChatGPT is essentially an expert level programmer in just about every language and can assist you with just about any task you are having from setting up your environment to debugging advanced, multi file software systems.
#
# ### It can not only read your code, but it can provide customized solutions for your problem on demand to help you fix your problems. We want to really emphasize how important this is. For about 99.9% of the coding errors you are facing, ChatGPT can and will solve them for you, for free (GPT3.5 works well most of the time, but GPT-4 (subscription) is even better). This is an unprecedented tool that you can leverage from the first day you start to learn to program.
#
# ### In addition to its 'knowledge', ChatGPT can also actively teach you the concepts that you are struggling to understand and provide you with real time information tailored to your specfic knowledge gaps. It is like having a personal tutor that you can ask for help on demand.
#
# ### We are just going to outright say it- **you should be using ChatGPT**. Some people will say it is cheating, some people disagree with it on a moral level to develop code, but we disagree with all of that. ChatGPT is simply another tool in your toolkit, but it just happens to be a diamond encrusted feather weight one shot kill long sword that you get for free on your first level. It is foolish not to take advantage of this tool to help you on your way.
#
# ### That being said, you should use the tool responsibly. While ChatGPT can and will write you complete algorithms, it does make mistakes, and just because it can do incredible things by no means implies that you shouldn't have to understand what it is doing. The whole point of the tool is to expedite your process, and your process includes knowing what the code you produce is doing and how it is managing your data. Stack Overflow is nice because you can see the commentary of a well educated communuity on people's answers, but you do not have that luxury with ChatGPT. It is the moral imperative of the user (YOU) to use ChatGPT wisely and not abuse the technology.
#
# ### So now that we have covered that you should use ChatGPT but you also should use it responsibly, let's talk about some ways to optimize it. Like any tool, you can get better at using ChatGPT over time (read up on `prompt engineering`), and there are some optimal ways. One of the most surefire ways to get the best answers out of ChatGPT are to type to it like you would talk to a human being clear and concise. A general format is `I am having this specific problem and this is my code. I have tried these things, and I get this error message as output. I need your help in understanding what this error means, how to fix it, and also how to learn about this problem so I can prevent it in the future` and underneath the message you could paste the relevant lines of code as well as the error message. 9 times out of 10, this will help you get your answer as well as some nice explanation on what is going on. From that point, you can work together with ChatGPT to tweak the results and get to a working solution. The more information you provide it the better, and the more context about your problem and goals the better as it will incorporate these into its response.
#
# ## **ArXiv**
#
# ### Arxiv (pronounced archive) is an open source repository of the newest papers being published in math, computer science, and other engineering focused fields. It is not peer reviewed so keep that in mind, but it is moderated and there many of the big papers in CS show up on ArXiv first and are worth reading if you are interested.
#
# ## **Broad Strokes Notes**
#
# ### In the theme of seeking coding help and trying to optimize our performance in this area, we also wanted to include a note here about how while all these resources exist and it is easy to find help, at the end of the day starting something brand new can be both hard and scary. As such, we wanted to also provide reassurance that the more you practice and work through this stuff the better you will get and the more comfortable you will feel.
#
# ### To help get you started on the right foot, the creators of Code Grand Rounds got together and put together a `What we wish we knew` list below. These are just some high yield quick factoids to get you going!
#
# ### `It can suck learning to code at first, but once you get a handle on it becomes so rewarding, and ultimately extremely fun!`
# ### `If your problem is too hard to google an answer you are working on a great problem`
# ### .......

# %% [markdown]
# # Coding Applications in Medicine: Computer Vision

# %% [markdown]
# ## Set Up

# %%
# Import the relevant packages
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
import os
from PIL import Image

#Set up the path
folder_path = os.getcwd()

# %%
ben = np.asarray(Image.open("ben.jpg"))

# %%
print(ben)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[  0   0   0]
#   [  0   0   0]
#   [  0   0   0]
#   ...
#   [ 82  54  66]
#   [ 83  56  65]
#   [ 83  57  66]]
#
#  [[  0   0   0]
#   [  0   0   0]
#   [  0   0   0]
#   ...
#   [ 81  54  61]
#   [ 82  55  60]
#   [ 83  56  61]]
#
#  [[  0   0   0]
#   [  0   0   0]
#   [  0   0   0]
#   ...
#   [ 84  54  62]
#   [ 84  54  62]
#   [ 82  53  58]]]

# %%
imgplot = plt.imshow(ben)

# %% [markdown]
# ## Cropping ##

# %%
cropped_ben = ben[700:1500,1900:2700,:]

# %%
imgplot = plt.imshow(cropped_ben)

# %% [markdown]
# ## Colors

# %%
# Make a copy of Ben
ben_GBR = ben.copy()
# Save a temporary copy of the Red channel 
benR = ben_new[:, :, 0]
# Set the R as G
ben_GBR[:, :, 0] = ben_GBR[:, :, 1]
# Set the G as B
ben_GBR[:, :, 1] = ben_GBR[:, :, 2]
# Set the B as old R
ben_GBR[:, :, 2] = benR

# %%
# Show the new image
imgplot = plt.imshow(ben_GBR)

# %%
ben_BRG = ben.copy()
## TODO: Revert the colors in the other way

# %% [markdown]
# ## Grayscale
# There are two ways to calculate grayscale:
# 1. (R+G+B)/3
# 2. 0.299R + 0.587G + 0.114B

# %%
# Option 1
ben_gray = (ben[:, :, 0] + ben[:, :, 1] + ben[:, :, 2])/3

# %%
# This doesn't look quite right
imgplot = plt.imshow(ben_gray, cmap='gray')

# %%
ben_gray_weighted = 0.299*ben[:, :, 0] + 0.587*ben[:, :, 1] + 0.114*ben[:, :, 2]

# %%
imgplot = plt.imshow(ben_gray_weighted, cmap='gray')

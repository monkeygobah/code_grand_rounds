# %% [markdown]
# # Data Science- K-Nearest Neighbors
#
# ### In this advanced data science topic, we will be exploring how the K-Nearest Neighbors (KNN) algorithm works. It will utilize concepts taught in module 3 such as pandas and dataframes. For this project we will be using a dataset from https://catalog.data.gov/dataset/covid-19-vaccinations-by-zip-code

# %% [markdown]
# ## Import Stuff

# %%
# Install and import all the neccessary stuff

# %pip install scikit-learn
# %pip install pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load data

# %% [markdown]
# ### First thing we will do is load the data into pandas and look at its structure. Let's take a look at the first few rows using ```df.head()``` to get a look at what we have.
#
# ### We also want to run ```df.info``` to get some metadata to save us some time from counting rows and columns by hand.

# %%
# Import the dataset
df = pd.read_csv('COVID-19_Vaccinations_by_ZIP_Code.csv', dtype={"Zip Code": "string", "Date": "string", "ZIP Code Location": "string", "Row_ID": "string"})

# Display the first few rows of the dataset
df.head()
# Out:
#   Zip Code        Date  Total Doses - Daily  Total Doses - Cumulative  \
# 0    60601  01/25/2021                   55                      1544
# 1    60601  01/26/2021                   65                      1609
# 2    60601  01/27/2021                   73                      1682
# 3    60601  02/07/2021                   23                      2412
# 4    60601  02/08/2021                   56                      2468
#
#    1st Dose - Daily  1st Dose - Cumulative  1st Dose - Percent Population  \
# 0                38                   1084                          0.072
# 1                41                   1125                          0.075
# 2                56                   1181                          0.078
# 3                17                   1745                          0.116
# 4                38                   1783                          0.118
#
#    Vaccine Series Completed - Daily  Vaccine Series Completed - Cumulative  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58020 entries, 0 to 58019
# Data columns (total 36 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Zip Code                                        58020 non-null  string
#  1   Date                                            58020 non-null  string
#  2   Total Doses - Daily                             58020 non-null  int64
#  3   Total Doses - Cumulative                        58020 non-null  int64
#  4   1st Dose - Daily                                58020 non-null  int64
#  5   1st Dose - Cumulative                           58020 non-null  int64
#  6   1st Dose - Percent Population                   56086 non-null  float64
#  7   Vaccine Series Completed - Daily                58020 non-null  int64
#  8   Vaccine Series Completed - Cumulative           58020 non-null  int64
# ...

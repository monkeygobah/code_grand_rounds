# %% [markdown]
# # Computer Vision Application: Diagnose Pneumonia

# %% [markdown]
# ### Time to put some of the computer vision skills to use. One of the most common medical images doctors encounter are X-rays, since they are so fast and easy. One of their many applications is to diagnose pneumonia. When a patient has pneumonia, there will be abnormal opacaties in the lungs (abnormally white pixels). An example is shown below. Fortunately for us, X-rays are in grayscale. This makes it very easy for us to practice a bunch of OpenCV and image processing operations.
#
# ![x-ray.png](attachment:x-ray.png)
# Image taken from https://www.news-medical.net/news/20201218/Transfer-learning-exploits-chest-Xray-to-diagnose-COVID-19-pneumonia.aspx.
#
# ### The goal of this project is, given an initial dataset of chest x-rays, we will use basic computer vision techniques (thresholding, color conversions, pixel counting, etc.) to try and make a pneumonia classifier. In other words, can we automatically have the computer diagnose a patient's pneumonia from just their X-ray alone? We will do this experimentally starting from the derivation of an intial cut-off value to use for thresholding to building our complete pipeline.

# %% [markdown]
# ## Import Relevant Packages

# %%
# Here we are going to install all of the packages we need for this notebook
# !pip install numpy
# !pip install matplotlib
# !pip install opencv-python

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt

# %% [markdown]
# ## Derive Initial Threshold Value
#
# ### Where should we begin? The abnormal finding in the X-ray is the opacities (white areas) on the lungs. If we want to isolate only the whiter pixels on the image, the thresholding function sounds like the perfect place to start. However, what cutoff value would give use the best results? We can determine the threshold value experimentally by testing a whole range of threshold values on a healthy X-ray and compare it to a diseased lung.
#
# ### Thus, we will first load a single example image of healthy and pneumonia X-ray. We will use this image to see if we can find an appropriate threshold value which nicely identifies the consolidation in the pneumonia X-rays. Once we import the image, we have to check to see if it is a color image or grayscale image. This can be done easily by checking the shape of the image. If there are three color channels, it is a color image. If there is only one color channel, it is already in grayscale.

# %%
# load images from your computer (change path to math where they are stored) 
healthy_example = cv2.imread('pneumonia_project_images/initial_xrays/healthy_xray.jpeg')
pneumonia_example = cv2.imread('pneumonia_project_images/initial_xrays/pneumonia_xray.jpeg')

# Remember the shape is represented as [width x height x channel]
print(healthy_example.shape)
print(pneumonia_example.shape)
# Out:
# (1024, 1024, 3)
# (425, 442, 3)

# %% [markdown]
# ### We only want to covert it to grayscale if necessary, so we can have the code check the shape of the image and then convert it to grayscale if it is in RGB format. Remember, we can do this using the `cvtColor` function from OpenCV.

# %%
# Check if the number of channels (.shape[2] == 3 as this would mean it is color image)
if len(healthy_example.shape) == 3 and healthy_example.shape[2] == 3: 
    # convert using cv2 if it is color (BGR2GRAY as images are loaded in BGR format from openCV instead of RGB)
    healthy_example = cv2.cvtColor(healthy_example, cv2.COLOR_BGR2GRAY) 
    print('converting healthy xray to grayscale')
    print(healthy_example.shape)

# Do the same thing for the pneumonia images
if len(pneumonia_example.shape) == 3 and pneumonia_example.shape[2] == 3:
    pneumonia_example = cv2.cvtColor(pneumonia_example, cv2.COLOR_BGR2GRAY)
    print('converting pneumonia xray to grayscale')
    print(pneumonia_example.shape)
# Out:
# converting healthy xray to grayscale
# (1024, 1024)
# converting pneumonia xray to grayscale
# (425, 442)

# %% [markdown]
# ### Now that we have the images in the grayscale, let's take a look at the images we're working with. We will be using the matplotlib `imshow` to see the images. We also want to look at this in grayscale, so we will set the color map (`cmap`) to gray.

# %%
# show the image, provide window name first
# matplotlib applies colormap by default so set colormap (cmap) to grey
plt.imshow(healthy_example,cmap='gray')
plt.title('Healthy xray')
plt.show()

plt.imshow(pneumonia_example, cmap='gray')
plt.title('Pneumonia xray')
plt.show()

# %% [markdown]
# ### We can see here that we loaded our data properly and that the images are in grayscale. If you compare the two images, we can see a clear image of a healthly lung in the first image. There are no white consolidations. When we look at the pneumonia lung, there is a lower right lobe consolidation (lower left of the image) due to the white appearance filling up where the black pixels should be.
#
# ### Let's try a few thresholding values to see if we can determine which value helps us best identify the consolidation. We will define a list of thresholds we want to try, and then apply them to every image sequentially to generate a bunch of thresholded images. From there, we will have to decide by eye what we believe is best for our purposes.
#
# ### In order to test all of the threshold values, we have to use a for loop which we learned in Module 1.

# %%
# List of thresholds
thresholds = [50, 75, 100, 125, 150]

# Loop over the thresholds
for thresh in thresholds:
    # Apply binary thresholding using opencv
    # ret is the threhsold value that was used. We dont need to worry about why we have to include it, but you will get a friendly error if you take it out!
    ret, healthy_threshold = cv2.threshold(healthy_example, thresh, 255, cv2.THRESH_BINARY)
    ret, pneumonia_threshold = cv2.threshold(pneumonia_example, thresh, 255, cv2.THRESH_BINARY)

    # Plot the thresholded images using the matplotlib library
    # subplot is just a way to show multiple figures on the same plot
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(healthy_threshold, cmap='gray')
    plt.title('Healthy xray, Threshold =' + str(thresh))

    plt.subplot(1, 2, 2)
    plt.imshow(pneumonia_threshold, cmap='gray')
    plt.title(f'Pneumonia xray, Threshold =' + str(thresh))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### When looking at the threshold values, 50, 75, and 100 all seem not quite right, since a lot of the clear lung field is loss when using these values. 150 is pretty good, but there is still some white detail that is lost from the healthy X-ray. Thus, 125 looks like a good value to use!
#
# ### Now that we have these thresholded images, what should we do with it? All we have are purely black and purely white pixels. What is the difference between healthy and diseased X-ray images? One quick way we can have the computer determine the difference is by counting the number of white pixels on the thresholded images. We expect the diseased image to have more white pixels due to the consolidation, so let's count the white pixels in each image after applying the threshold.

# %% [markdown]
# ## Count White Pixels and Normalize

# %%
# Thresholding the images again
ret, healthy_threshold = cv2.threshold(healthy_example, 125, 255, cv2.THRESH_BINARY)
ret, pneumonia_threshold = cv2.threshold(pneumonia_example, 125, 255, cv2.THRESH_BINARY)

# Count white pixels
white_pixels_healthy = np.count_nonzero(healthy_threshold == 255)
white_pixels_pneumonia = np.count_nonzero(pneumonia_threshold == 255)

print('The number of white pixels in the healthy X-ray is: ' + str(white_pixels_healthy))
print('The number of white pixels in the pneumonia X-ray is: ' + str(white_pixels_pneumonia))
# Out:
# The number of white pixels in the healthy X-ray is: 588026
# The number of white pixels in the pneumonia X-ray is: 130848

# %% [markdown]
# ### Wait, that doesn't make sense. The white pixels should correlate to the amount of consolidation and we SAW that there is more consolidation in the pneumonia image. So what went wrong? OH! We need to consider the SIZE of the IMAGE! If the image is larger, there will be an overall higher number of pixels. Therefore, we have to consider how many white pixels there are with respect to the overall number of pixels. Let's normalize the number of white pixels to the total number of pixels which we can get using `size`. This is essentially the same as determine the percentage of the image that is composed of white pixels.

# %%
# we take the value we got earlier and divide it by the total size of the image!
normalized_white_pix_healthy = white_pixels_healthy / healthy_threshold.size
normalized_white_pix_pneumonia = white_pixels_pneumonia / pneumonia_threshold.size

print(normalized_white_pix_healthy)
print(normalized_white_pix_pneumonia)
# Out:
# 0.5607852935791016
# 0.6965557625765239

# %% [markdown]
# ### This looks more like what we expected.  Now that we have the thresholded images and the feature we're going to use to determine if they are healthy or not, let's try to set the ratio of white pixels to total pixels that define pneumonia based on a few images of healthy X-rays.

# %% [markdown]
# ## Identify Cutoff Ratio for Healthy X-Rays
#
# ### In order to go through many files, we will be using a packaged called os that let's you go through files on your computer faster. Then, from there we will be performing the same algorithm that we developed above: import th image, threshold the image using the cutoff value we determined, count the white pixels, and find the ratio. After finding the ratio on these health X-rays, we do some statistical analyses on the ratios such as the minimum, maximum, and average ratio.

# %%
## CHANGE THIS TO FIT YOUR PATH
healthy_path = 'pneumonia_project_images/healthy_xrays'
print(os.getcwd())
#define a list to store the data we accumulate
white_pix_ratio_list = []
for root, dirs, files in os.walk(healthy_path):
    for file in files:
        if file.endswith('jpeg') or file.endswith('png') or file.endswith('jpg'):
            #make path to image as we walk through every image in the healthy xrays folder. Again, dont really need to understand how, just know thats what it does
            path = os.path.join(root, file)
            # load image using opencv
            image = cv2.imread(path)
            # Check if images are in RGB format and convert to grayscale if necessary
            if len(image.shape) == 3 and image.shape[2] == 3:
                image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            # apply threshold using 125 like we determined earlier
            ret, threshold_image = cv2.threshold(image, 125, 255, cv2.THRESH_BINARY)
            # Count white pixels
            white_pixels = np.count_nonzero(threshold_image == 255)   
            #normalize to image size
            normalized_white_pix = white_pixels / threshold_image.size
            #store the ratio of white pixels to image size in the earlier list we made 
            white_pix_ratio_list.append(normalized_white_pix)

# calculate average, min, and max of list to get some more useful data to make disgnoses with
avg_healthy_ratio = sum(white_pix_ratio_list)/len(white_pix_ratio_list)
max_healthy_ratio = max(white_pix_ratio_list)
min_healthy_ratio = min(white_pix_ratio_list)
print('average is:' + str(avg_healthy_ratio))
print('maximum is:' + str(max_healthy_ratio))
print('minimum is:' + str(min_healthy_ratio))
# Out:
# C:\Users\timtp\Documents\code_md\module_4_Computer_Vision\diagnose_pneumonia_project
# average is:0.49187054675437997
# maximum is:0.5955089583003013
# minimum is:0.3399213411727316

# %% [markdown]
# ### We got a value of .49 as the average of the 5 images we tested. The max is .59 and the minimum is 0.33. Now we have to decide what we want our cutoff value should be. There are a few things we need to consider when making the cutoff value. For example, we want to decide if we want our test to be sensitive or specific. If our test is highly specific, there we will have more false negatives, but the number of true positives will be maximized (C). If we make the test highly sensitive, we will have more false positive, but the number of true negatives will be maximized (A).
#
# ![senspec.png](attachment:senspec.png)
# Image taken from https://www.publichealthnotes.com/sensitivity-vs-specificity-10-important-differences/
#
# ### Let's try to make a highly specific algorithm and use a value of .61 as the threshold. You can also play around with the threshold later to see if you can get a better result.

# %% [markdown]
# ## Identify Pneumonia X-Rays
#
# ### Now let's incorporate the 0.61 ratio threshold into our algorithm. We will import the pneumonia images, threshold the image using the 125 value we determined earlier, count the white pixels, and then calculate the ratio of white pixels to total pixels. If the ratio we calculate is higher than 0.61, we will say that the X-ray is a pneumonia image. At the end, we can count how many images we classified correctly. If we classify the image wrong, we can take a look at what the ratio was.

# %%
# Set the threshold as determined above
ratio_threshold = .61

## CHANGE THIS TO FIT YOUR PATH
pneumo_path = 'pneumonia_project_images/pneumonia_xrays'


# make a list to store the final diagnoses
diagnosis_list = []
for root, dirs, files in os.walk(pneumo_path):
    for file in files:
        if file.endswith('jpeg') or file.endswith('png') or file.endswith('jpg'):
            #make path to image as we walk through every image in the healthy xrays folder. Again, dont really need to understand how, just know thats what it does
            path = os.path.join(root, file)
            # load image using opencv
            image_pneumonia = cv2.imread(path)
            # Check if images are in RGB format and convert to grayscale if necessary
            if len(image_pneumonia.shape) == 3 and image_pneumonia.shape[2] == 3:
                image_pneumonia = cv2.cvtColor(image_pneumonia, cv2.COLOR_BGR2GRAY)
            # apply threshold using 125 like we determined earlier
            ret, threshold_image_pneu = cv2.threshold(image_pneumonia, 125, 255, cv2.THRESH_BINARY)
            # Count white pixels
            white_pixels_pneu = np.count_nonzero(threshold_image_pneu == 255)   
            #normalize to image size
            normalized_white_pix_pneu = white_pixels_pneu / threshold_image_pneu.size
            # Compare the white pixels to the ratio from above to make a diagnosis!
        
            if normalized_white_pix_pneu > ratio_threshold:
                diagnosis_list.append('Pneumonia')
            else:
                diagnosis_list.append('Healthy')
                print(normalized_white_pix_pneu)

# Print the final diagnosis list to see how many we got right

print(diagnosis_list)
# Out:
# 0.5182900131353739
# ['Pneumonia', 'Pneumonia', 'Healthy', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia']

# %% [markdown]
# ## Recap
#
# ### We got 90% correct! Not bad! The only image that was misclassified had a ratio of 0.52 which was close to the average ratio for healthy images. It makes sense that we can't get a 100% accuracy, because of the overlap of diseased and non-diseased individuals
#
# ### Obviously, you would never use this tool clinically. Even in our data, we had a wide range of variance, and we didnt take into account key features such positioning of the patient in the xray, scope of the xray image, xray machine settings, etc. In practice, you might want to build a convolutinoal neural network to solve a problem such as this, but we hope this gave you a good introduction to some core principles in comptuter vision and showed how this type of technology can be used in clinical settings! Play around with the notebook / import your own or more data and see if you can make it even better!
